# %%
2+1
# Out:
# 3

# %%
3-2
# Out:
# 1

# %% [markdown]
# HI THIS IS R

# %%
5+6
# Out:
# 11

# %%
3**2
# Out:
# 9

# %%
6//4
# Out:
# 1

# %%
6%4
# Out:
# 2

# %%
100 % 75
# Out:
# 25

# %%
6-2
# Out:
# 4

# %%
8+2
# Out:
# 36

# %%
44/6 + 5
# Out:
# 12.333333333333332

# %%
x=2
y=3
x+y
# Out:
# 5
